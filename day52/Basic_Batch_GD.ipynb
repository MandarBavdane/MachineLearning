# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [80.95452769]
# -2.3108319969379694

# %%
m = 21.40

# %%
class GDRegressor:
    
    def __init__(self, learning_rate, epochs):
        self.m = 21.40
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self, X, y):
        # Calculate b using GD
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(loss_slope, self.b)
        print(self.b)

# %%
gd = GDRegressor(0.001, 100) # When it hallicunates, reduce LR, increase Epochs

# %%
gd.fit(X,y)
# Out:
# -23954.112620850276 -96.04588737914972
# -19163.29009668022 -76.8825972824695
# -15330.632077344177 -61.55196520512533
# -12264.505661875339 -49.28745954324999
# -9811.604529500271 -39.475855013749715
# -7849.283623600218 -31.626571390149497
# -6279.426898880174 -25.347144491269322
# -5023.541519104139 -20.323602972165183
# -4018.8332152833113 -16.30476975688187
# -3215.0665722266494 -13.089703184655221
# -2572.0532577813196 -10.5176499268739
# -2057.642606225055 -8.460007320648845
# -1646.1140849800436 -6.813893235668802
# -1316.8912679840355 -5.497001967684767
# -1053.5130143872288 -4.443488953297538
# -842.8104115097822 -3.600678541787756
# -674.2483292078261 -2.9264302125799295
# -539.398663366261 -2.3870315492136687
# -431.51893069300854 -1.9555126185206602
# -345.2151445544066 -1.6102974739662534
# -276.17211564352544 -1.334125358322728
# -220.93769251482024 -1.1131876658079076
# -176.75015401185686 -0.9364375117960507
# -141.4001232094854 -0.7950373885865654
# -113.12009856758758 -0.6819172900189778
# -90.49607885407046 -0.5914212111649073
# -72.39686308325686 -0.5190243480816504
# -57.91749046660475 -0.46110685761504566
# -46.33399237328423 -0.41477286524176143
# -37.06719389862687 -0.37770567134313454
# -29.6537551189017 -0.3480519162242328
# -23.72300409512181 -0.324328912129111
# -18.978403276096984 -0.30535050885301407
# -15.18272262087801 -0.29016778623213607
# -12.146178096702315 -0.27802160813543375
# -9.716942477361897 -0.2683046656580719
# -7.773553981889435 -0.2605311116761824
# -6.218843185511517 -0.2543122684906709
# -4.975074548409125 -0.24933719394226178
# -3.98005963872761 -0.24535713430353417
# -3.1840477109815595 -0.24217308659255263
# -2.54723816878537 -0.23962584842376725
# -2.037790535028563 -0.23758805788873869
